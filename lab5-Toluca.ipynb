# %%
import pandas as pd
df = pd.read_csv('toluca.csv')
df.head()
# Out:
#    lotSize  workHours
# 0       80        399
# 1       30        121
# 2       50        221
# 3       90        376
# 4       70        361

# %%
df.plot(kind='scatter', x='lotSize', y='workHours')

# %%
import seaborn as sns
plot = sns.lmplot(y='workHours', x='lotSize', data=df)

# %%
resid = sns.residplot('lotSize', 'workHours', data=df)
resid.set(xlabel='lotSize', ylabel='residuals')
# Out:
# [Text(0, 0.5, 'residuals'), Text(0.5, 0, 'lotSize')]

# %%
from sklearn.linear_model import LinearRegression

linReg = LinearRegression()
linReg.fit(df.drop('workHours', axis=1), df.iloc[:, 1])
linReg
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
linReg.coef_
# Out:
# array([3.57020202])

# %%
linReg.intercept_
# Out:
# 62.36585858585849

# %%
# The predictor workHours is suitable for SLR
